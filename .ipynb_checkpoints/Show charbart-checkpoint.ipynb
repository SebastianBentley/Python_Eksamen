# %%
import laptops_data
import matplotlib.pyplot as plt
the_dict = laptops_data.load_data()
#laptops_data.make_bar_chart(the_dict)
plt.bar(the_dict.keys(), the_dict.values())
fig1=plt.gcf()
plt.xticks(rotation=28.5)
fig1.savefig("barchart.png", dpi=400)
plt.figure(figsize=(20,10))
plt.show()
